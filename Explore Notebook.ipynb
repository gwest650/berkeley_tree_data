# %% [markdown]
# # Exploring Data

# %%
import pandas as pd
import altair as alt
# Out:
# /Users/gracelynnewest/.pyenv/versions/3.8.5/envs/berkeley_tree_data-3.8.5/lib/python3.8/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
pd.set_option('display.max_columns', None)

# %%
berkeley_trees = pd.read_csv('City_Trees.csv')

# %%
berkeley_trees.head()
# Out:
#                                          the_geom  SiteID  STRT_NUM  \
# 0    POINT (-122.27825103970729 37.8849535051094)   19143      1161
# 1   POINT (-122.27816635887888 37.88496491806563)   19144      1161
# 2   POINT (-122.27803245597467 37.88489176163965)   19145      1708
# 3  POINT (-122.27795279613872 37.884872693418004)   19146      1708
# 4  POINT (-122.27787858593904 37.884855236280394)   19147      1712
#
#      STRT_NAM STRT_ASSIG    BLOCK_ON                  SPECIES ITREE  \
# 0  COLUSA AVE          N  BEVERLY PL        Prunus cerasifera  PRCE
# 1  COLUSA AVE          N  BEVERLY PL  Liquidambar styraciflua  LIST
# 2  BEVERLY PL          N  BEVERLY PL            Planting Site   NaN
# 3  BEVERLY PL          N  BEVERLY PL            Planting Site   NaN
# 4  BEVERLY PL          N  BEVERLY PL            Acer  species    AC
#
#     Common_Nam OTHER_TREE ICON_TYPE LOCATION      GROWSPACE  P_STRIP_WI  \
# ...

# %%
berkeley_trees.tail()
# Out:
#                                              the_geom  SiteID  STRT_NUM  \
# 46032  POINT (-122.27422705818493 37.871332060519464)   33284      1820
# 46033   POINT (-122.27442956186094 37.87117125868647)   33285      1814
# 46034   POINT (-122.27468758058076 37.87123767665735)   33286      1810
# 46035   POINT (-122.27478407603465 37.87115416164091)   33287      1808
# 46036    POINT (-122.2749554349902 37.87113427284294)   33288      1800
#
#               STRT_NAM STRT_ASSIG         BLOCK_ON                  SPECIES  \
# 46032  M L KING JR WAY          N  M L KING JR WAY  Liriodendron tulipifera
# 46033   UNIVERSITY AVE          N   UNIVERSITY AVE  Liriodendron tulipifera
# 46034   UNIVERSITY AVE          N   UNIVERSITY AVE            Planting Site
# 46035   UNIVERSITY AVE          N   UNIVERSITY AVE  Liriodendron tulipifera
# 46036   UNIVERSITY AVE          N   UNIVERSITY AVE  Liriodendron tulipifera
#
#       ITREE  Common_Nam OTHER_TREE  ... CURB GUARD SPACESIZE  \
# ...

# %%
berkeley_trees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46037 entries, 0 to 46036
# Data columns (total 42 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   the_geom    46037 non-null  object
#  1   SiteID      46037 non-null  int64
#  2   STRT_NUM    46037 non-null  int64
#  3   STRT_NAM    46037 non-null  object
#  4   STRT_ASSIG  46037 non-null  object
#  5   BLOCK_ON    43257 non-null  object
#  6   SPECIES     46037 non-null  object
#  7   ITREE       35417 non-null  object
#  8   Common_Nam  35417 non-null  object
#  9   OTHER_TREE  2261 non-null   object
#  10  ICON_TYPE   46037 non-null  object
#  11  LOCATION    46025 non-null  object
#  12  GROWSPACE   46037 non-null  object
#  13  P_STRIP_WI  31361 non-null  float64
#  14  SWK_WIDTH   39493 non-null  float64
#  15  DBH_IN      44851 non-null  float64
#  16  HEIGHT_FT   35077 non-null  float64
#  17  SPREAD_FT   34801 non-null  float64
#  18  STEM_NUM    34802 non-null  float64
# ...
